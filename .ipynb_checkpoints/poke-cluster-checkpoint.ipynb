# %% [markdown]
# # Data Science com Pokémon - Estudo
#
# ### Por Guilherme Ceratti Ramos

# %% [markdown]
#     Esse Notebook servirá como um estudo pessoal no aprendizado de Data Science. O tema, portanto, foi escolhido levando em conta alguns fatores:
#
#         1) O tamanho do Dataset, tanto em colunas quanto em linhas: não é grande demais, mas é o suficiente para me permitir entender e começar meu     treinamento nos diversos processos de um projeto de Data Science;
#
#         2) O meu gosto pelo tema. Um professor da faculdade certa vez me disse que é muito bom estudar com assuntos que gostamos, mesmo que apenas no início, antes de lidarmos com problemas reais. Unimos o útil ao agradável;
#
#         3) O modo como o tema pode ser utilizado. Pokémons possuem diversos status e tipos. É o exemplo perfeito para o treinamento de um algoritmo de clusterização e/ou classificação.

# %% [markdown]
# ### Perguntas a serem respondidas utilizando esse estudo:
#
#         1) É possível construir um classificador para identificar Pokémons lendários?
#         2) Como altura e peso de um Pokémon se correlacionam com seus status base?
#         3) Que fatores influenciam o Experience Growth e Egg Steps? Essas quantidades são correlacionadas?
#         4) Qual tipo é o mais forte, no geral? E qual o mais fraco?
#         5) Qual tipo possui maior probabilidade de ser um Pokémon lendário?
#
#         [DESAFIO] Pode-se construir um "dream team" de Pokémon? Isso é, um time de 6 Pokémon que inflige maior dano se mantendo resistente a qualquer  outro time de 6 Pokémon.

# %% [markdown]
# ## Parte 0 - Importações e organização do ambiente

# %%
# !pip install requests
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# !python -m pip install -U matplotlib
# !pip install -U scikit-learn
# Out:
# ...
# Requirement already up-to-date: matplotlib in c:\users\guilherme.ceratti\anaconda3\lib\site-packages (3.4.2)
# ...
# Requirement already up-to-date: scikit-learn in c:\users\guilherme.ceratti\anaconda3\lib\site-packages (0.24.2)
# ...

# %%
import pandas as pd

# %%
dataset = pd.read_csv('pokemon.csv')
dataset.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...
